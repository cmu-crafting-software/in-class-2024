# %%
import pandas as pd

# %%
first = pd.read_csv('data/gapminder_all.csv', index_col='country')
first
# Out:
#                continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria           Africa     2449.008185     3013.976023     2550.816880
# Angola            Africa     3520.610273     3827.940465     4269.276742
# Benin             Africa     1062.752200      959.601080      949.499064
# Botswana          Africa      851.241141      918.232535      983.653976
# Burkina Faso      Africa      543.255241      617.183465      722.512021
# ...                  ...             ...             ...             ...
# Switzerland       Europe    14734.232750    17909.489730    20431.092700
# Turkey            Europe     1969.100980     2218.754257     2322.869908
# United Kingdom    Europe     9979.508487    11283.177950    12477.177070
# Australia        Oceania    10039.595640    10949.649590    12217.226860
# New Zealand      Oceania    10556.575660    12247.395320    13175.678000
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# ...

# %%
second = first[first['continent'] == 'Americas']
second
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
third = second.drop('Puerto Rico')
third
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
fourth = third.drop('continent', axis = 1)
fourth
# Out:
#                      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina               5911.315053     6856.856212     7133.166023
# Bolivia                 2677.326347     2127.686326     2180.972546
# Brazil                  2108.944355     2487.365989     3336.585802
# Canada                 11367.161120    12489.950060    13462.485550
# Chile                   3939.978789     4315.622723     4519.094331
# Colombia                2144.115096     2323.805581     2492.351109
# Costa Rica              2627.009471     2990.010802     3460.937025
# Cuba                    5586.538780     6092.174359     5180.755910
# Dominican Republic      1397.717137     1544.402995     1662.137359
# Ecuador                 3522.110717     3780.546651     4086.114078
# El Salvador             3048.302900     3421.523218     3776.803627
# Guatemala               2428.237769     2617.155967     2750.364446
# Haiti                   1840.366939     1726.887882     1796.589032
# ...

# %%
fourth.to_csv('result.csv')

# %%
europe_gdp_data = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
print(europe_gdp_data.iloc[0:2, 0:2])
print(europe_gdp_data.loc['Albania':'Belgium', 'gdpPercap_1952':'gdpPercap_1962'])
# Out:
#          gdpPercap_1952  gdpPercap_1957
# country
# Albania     1601.056136     1942.284244
# Austria     6137.076492     8842.598030
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Albania     1601.056136     1942.284244     2312.888958
# Austria     6137.076492     8842.598030    10750.721110
# Belgium     8343.105127     9714.960623    10991.206760

# %%
# 4. a)
AllGDP = pd.read_csv('data/gapminder_all.csv')
GDPfor1982 = AllGDP.iloc[0:,8]
GDPfor1982
# Out:
# 0       5745.160213
# 1       2756.953672
# 2       1277.897616
# 3       4551.142150
# 4        807.198586
#            ...
# 137    28397.715120
# 138     4241.356344
# 139    18232.424520
# 140    19477.009280
# 141    17632.410400
# Name: gdpPercap_1982, Length: 142, dtype: float64

# %%
# 4. b)
EurGDP = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
Den = EurGDP.loc['Denmark', :]
Den
# Out:
# gdpPercap_1952     9692.385245
# gdpPercap_1957    11099.659350
# gdpPercap_1962    13583.313510
# gdpPercap_1967    15937.211230
# gdpPercap_1972    18866.207210
# gdpPercap_1977    20422.901500
# gdpPercap_1982    21688.040480
# gdpPercap_1987    25116.175810
# gdpPercap_1992    26406.739850
# gdpPercap_1997    29804.345670
# gdpPercap_2002    32166.500060
# gdpPercap_2007    35278.418740
# Name: Denmark, dtype: float64

# %%
# 4. c)
After1985 = AllGDP.iloc[0:, 9:]
After1985
# Out:
#      gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0       5681.358539     5023.216647     4797.295051     5288.040382
# 1       2430.208311     2627.845685     2277.140884     2773.287312
# 2       1225.856010     1191.207681     1232.975292     1372.877931
# 3       6205.883850     7954.111645     8647.142313    11003.605080
# 4        912.063142      931.752773      946.294962     1037.645221
# ..              ...             ...             ...             ...
# 137    30281.704590    31871.530300    32135.323010    34480.957710
# 138     5089.043686     5678.348271     6601.429915     6508.085718
# 139    21664.787670    22705.092540    26074.531360    29478.999190
# 140    21888.889030    23424.766830    26997.936570    30687.754730
# 141    19007.191290    18363.324940    21050.413770    23189.801350
#
#      gdpPercap_2007  lifeExp_1952  lifeExp_1957  lifeExp_1962  lifeExp_1967  \
# ...
